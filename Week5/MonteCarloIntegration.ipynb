# %% [markdown]
# Exercise 1:
# --

# %%
f = lambda x: x**(0.5) + sin(x)

# %%
x = arange(0.,15.,0.001)

# %%
myplot = plot(x,f(x),lw = 3)
ylabel(r'$x^{1/2} + \sin(x)$', fontsize = 20)
xlabel(r'$x$', fontsize = 20)
xlim(0.,15.)

show()

# %%
xmin = 1.7
xmax = 12.4

subx = x[logical_and((x>xmin),(x<xmax))]
ymax = max(f(subx))*1.05
ymin = 0.

myplot = plot(x,f(x),lw=3)
xlim(0.,15.)

plot([xmin,xmin],[ymin,ymax],color='k', linestyle='--')
plot([xmax,xmax],[ymin,ymax],color='k', linestyle='--')
plot([xmin,xmax],[ymax,ymax],color='k', linestyle='--')

show()

# %%
N = 100000000
samples_x = xmin + (xmax-xmin)*random_sample(N);
samples_y = ymin + (ymax-ymin)*random_sample(N);

myplot = plot(x,f(x),lw = 3)
xlim(0.,15.)

plot(samples_x[1:200], samples_y[1:200],'.')

plot([xmin,xmin],[ymin,ymax],color='k', linestyle='--')
plot([xmax,xmax],[ymin,ymax],color='k', linestyle='--')
plot([xmin,xmax],[ymax,ymax],color='k', linestyle='--')

show()

# %%
newmask = (samples_y < f(samples_x))
sum(newmask)
# Out:
# 61813686

# %%
myplot = plot(x,f(x),lw = 3)
xlim(0.,15.)

plot(samples_x[1:200], samples_y[1:200],'.')

plot(samples_x[newmask[:200]],samples_y[newmask[:200]],'r.')

plot([xmin,xmin],[ymin,ymax],color='k', linestyle='--')
plot([xmax,xmax],[ymin,ymax],color='k', linestyle='--')
plot([xmin,xmax],[ymax,ymax],color='k', linestyle='--')

show()

# %%
I = (xmax-xmin)*(ymax-ymin)*sum(newmask)/newmask.size
print I
# Out:
# 26.517032753

# %%
#time for the exact!

# %%
Iana = lambda x: (2./3.)*x**(3./2.)-cos(x)
Iexact = Iana(xmax)-Iana(xmin)
Ierr = 100*(Iexact-I)/Iexact
print "I_exact =", Iexact
print "I_hitormiss =",I
print "Error on I =",Ierr,"%"
# Out:
# I_exact = 26.5172145362
# I_hitormiss = 26.517032753
# Error on I = 0.000685529051266 %

# %% [markdown]
# Exercise 2:
# --

# %%
N=10000
a = xmin
b = xmax

samples_x = xmin + (xmax-xmin)*random_sample(N);

total = sum(f(samples_x))

I = (b-a)*(total/N)
print I
# Out:
# 26.4988130912

# %%
myplot = plot(x,f(x),lw = 3)
xlim(0.,15.)



plot([xmin,xmax],[total/N,total/N], 'r', lw = 3)

plot([xmin,xmin],[ymin,ymax],color='k', linestyle='--')
plot([xmax,xmax],[ymin,ymax],color='k', linestyle='--')
plot([xmin,xmax],[ymax,ymax],color='k', linestyle='--')

show()

# %%
Iana = lambda x: (2./3.)*x**(3./2.)-cos(x)
Iexact = Iana(xmax)-Iana(xmin)
Ierr = 100*(Iexact-I)/Iexact
print "I_exact =", Iexact
print "I_hitormiss =",I
print "Error on I =",Ierr,"%"
# Out:
# I_exact = 26.5172145362
# I_hitormiss = 26.4988130912
# Error on I = 0.0693943362105 %

# %% [markdown]
# This method get us similar similar results, but is muh mush faster!

# %% [markdown]
# Exercise 3:
# --

# %%
import sys
sys.path.insert(0,'../Week4')

from Electrostatics import *

sigma = 2e-9
N = 1e4;
x0 = 2.;
y0 = 3.;
ri = 0. + 0.012*random_sample(N);
thetai = 0. + (2*pi)*random_sample(N);

Vi = pointPotential(x0, y0, sigma, ri, thetai);

Vtot = (0.012*2.*pi/N)*sum(Vi)
print Vtot
# Out:
# 8.18526607682e-34

# %%
#I dont know if thats right or not, but it seems realistic
