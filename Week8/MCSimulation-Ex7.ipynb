# %%
import numpy.random

# %%
print numpy.random.random(5)
print numpy.random.random(5)
# Out:
# [ 0.15206734  0.98187985  0.77489296  0.26379935  0.77986146]
# [ 0.87222095  0.25752902  0.1449664   0.60810557  0.30657671]

# %%
#now we set the seed
numpy.random.seed(4242)
print 'using seed = 4242'
print numpy.random.random(5)
# Out:
# using seed = 4242
# [ 0.32494949  0.94041458  0.91400794  0.28650938  0.78180262]

# %%
numpy.random.seed(None)
print 'using seed = None'
print numpy.random.random(5)
# Out:
# using seed = None
# [ 0.57126551  0.5368861   0.64412025  0.74028989  0.83798853]

# %%
numpy.random.seed(4242)
print 'using seed = 4242, should be the same as before'
print numpy.random.random(5)
# Out:
# using seed = 4242, should be the same as before
# [ 0.32494949  0.94041458  0.91400794  0.28650938  0.78180262]

# %%
numpy.random.seed(None)
z = numpy.random.random(100000)
hist(z,100,normed=True)
plot([0,1.],[1.,1.], 'r-',lw=3)
xlabel("x", fontsize=20)
ylabel("samples probability",fontsize=20)
show()

# %% [markdown]
# #Example 1

# %%
x = arange(0.,pi+0.001,0.01)
f = lambda x: sin(x)/2.
F = lambda x: (cos(0)-cos(x))/2.
    
plot(x,f(x),label='True distribution',lw=3)
plot(x,F(x),label='Cumulative function',lw=3)

xlim(0,3.5)
ylim(0,1.1)

legend(loc=0)
show()

# %%
#number of samples
N=10000

#N random numbers between 0 and 1
z = numpy.random.random_sample(N);

#inverse CDF
Finv = lambda z:arccos(cos(0)-2*z)

#sampled x values
xsamples = Finv(z);

#how do they compare to the original
hist(xsamples,50,normed=True,label='Samples distribution')
plot(x,f(x),label='True distribution',lw=3,color='red')

xlim(0,pi)
ylim(0,0.7)

legend(loc=0)
show()

# %% [markdown]
# #Exercise 1

# %% [markdown]
# $F(x) = \int_{0}^x \lambda e^{-\lambda t}dt = -e^{-\lambda x} + e^{0}$

# %% [markdown]
# $F^{-1}(x)=\frac{ln(1-x)}{-\lambda}$

# %%
f = lambda x: lam*exp(-lam*x)
F = lambda x: -exp(-lam*x)+1
Finv = lambda x: log(1-x)/(-lam)

lam = 1
x = arange(0,5.01,0.01)
plot(x,f(x), label = 'True Distribution',lw=3)
plot(x,F(x),label='Cumulative function',lw=3)
legend(loc = 0)
show()

# %%
#number of samples
N=10000

#N random numbers between 0 and 1
z = numpy.random.random_sample(N);

#sampled x values
xsamples = Finv(z);

#how do they compare to the original
hist(xsamples,50,normed=True,label='Samples distribution')
plot(x,f(x),label='True distribution',lw=3,color='red')
show()

# %% [markdown]
# #Exercise 2

# %%
x = arange(0,5.01,0.01)
dist = f(x)
CDF = cumsum(dist)/sum(dist)
N = 10000
z = numpy.random.random(N)
Finv = x[searchsorted(CDF,z)]
hist(Finv,50,normed=True,label='Samples distribution')
plot(x,dist,label='True Distribution',lw = 3)
plot(x,CDF,label='CDF',lw=3)
legend(loc=0)
show()

# %%
def distribute1D(x,prob,N):
    """takes any numerical distribution prob, on the intercal defined by the array x, and returns an array of N sampled values that are statistically the same as the input data"""
    dist = prob(x)
    CDF = cumsum(dist)/sum(dist)
    z = numpy.random.random(N)
    Finv = x[searchsorted(CDF,z)]
    return Finv

test = distribute1D(x,f,N)
hist(test,50,normed=True,label='Samples distribution')
show()

# %% [markdown]
# #Exercise 3

# %%
d = 15*(10**-6) #15 micro meters
a = 10*(10**-6) #10 micro meters
L = 1 #1 meter
lam = 632.8*(10**-9) #632.8 nano meters

sinc = lambda x: sin(pi*x)/(pi*x)
I_diff = lambda x: sinc((a*x)/(lam*L))**2
I_int = lambda x: cos((2*pi*d*x)/(lam*L))**2
I_tot = lambda x: I_diff(x) * I_int(x)

N = 10000 #10,000 photons! 
x = arange(-0.2,0.201,0.001)
this = distribute1D(x,I_tot,N)
n,bins,patches=hist(this,400,normed=True,label='Samples distribution')
plot(x,I_tot(x)*max(n),'r')
xlim(-0.2,0.2)
show()

# %%
N = 1 #1 photon! 
x = arange(-0.2,0.201,0.001)
this = distribute1D(x,I_tot,N)
that = numpy.random.random_sample(N)
scatter(this,that)
xlim(-0.2,0.2)
show()

# %%
N = 10 #10 photons! 
x = arange(-0.2,0.201,0.001)
this = distribute1D(x,I_tot,N)
that = numpy.random.random_sample(N)
scatter(this,that)
xlim(-0.2,0.2)
show()

# %%
N = 100 #100 photons! 
x = arange(-0.2,0.201,0.001)
this = distribute1D(x,I_tot,N)
that = numpy.random.random_sample(N)
scatter(this,that)
xlim(-0.2,0.2)
show()

# %%
N = 1000 #1,000 photons! 
x = arange(-0.2,0.201,0.001)
this = distribute1D(x,I_tot,N)
that = numpy.random.random_sample(N)
scatter(this,that)
xlim(-0.2,0.2)
show()

# %%
N = 10000 #10,000 photons! 
x = arange(-0.2,0.201,0.001)
this = distribute1D(x,I_tot,N)
that = numpy.random.random_sample(N)
scatter(this,that)
xlim(-0.2,0.2)
show()

# %% [markdown]
# You can see how as we sample more and more photons you see it behave more and more like the distribution!

# %% [markdown]
# Exercise Question 2:
# =

# %%
f = lambda x: alpha*(beta**(-alpha))*(x**(alpha-1))*exp(-(x/beta)**alpha)
CDF = lambda x: 1-exp(-(x/beta)**(alpha))
Finv = lambda x: beta*(-log(1-x))**(1/alpha)

alpha = 1.5
beta = 6

N = 100000
x = arange(0,30,0.001)
z = numpy.random.random_sample(N);
xsamples = Finv(z);
hist(xsamples,50,normed=True,label='Samples distribution')
plot(x,f(x),label='True distribution',lw=3,color='red')
plot(x,CDF(x),label='CDF',lw=3,color='green')
xlim(0,15)
legend(loc=0)
show()

#close up
hist(xsamples,50,normed=True,label='Samples distribution')
plot(x,f(x),label='True distribution',lw=3,color='red')
title('Close up of Distribution')
legend(loc=0)
show()

# %% [markdown]
# Exercise Question 3:
# =

# %%
f = lambda x: 60*(x**3)*((1-x)**2)

xmin = 0
xmax = 1
ymin = 0
ymax = 2.0736
N = 100000000
samples_x = xmin + (xmax-xmin)*random_sample(N);
samples_y = ymin + (ymax-ymin)*random_sample(N);

x = arange(0,1.01,0.01)
myplot = plot(x,f(x),lw = 3)
xlim(0.,1.)

plot(samples_x[1:200], samples_y[1:200],'.')
newmask = (samples_y < f(samples_x))
plot(samples_x[newmask[:200]],samples_y[newmask[:200]],'r.')
plot([xmin,xmin],[ymin,ymax],color='k', linestyle='--')
plot([xmax,xmax],[ymin,ymax],color='k', linestyle='--')
plot([xmin,xmax],[ymax,ymax],color='k', linestyle='--')
show()

# %%
xsamples = samples_x[newmask];
CDF = cumsum(f(x))/sum(f(x))
plot(x,f(x),lw = 3, label='True Distribution')
plot(x,CDF,lw=3,label='CDF')
hist(xsamples,50,normed=True,label='Samples distribution')
legend(loc=0)
show()
